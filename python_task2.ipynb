# %%
customer = {"name": "Amit", "balance": 5000}
if customer ["balance"] > 3000:
    print("Good balance")
else:
    print("Low balance")
# Out:
# Good balance

# %%
account = ("Priya", "Savings")
if account[1] == "Savings":
    print("Savings Account")
# Out:
# Savings Account

# %%
type(account)
# Out:
# tuple

# %%
customer=["Arhaan","Prajwal","Keerthan"]                                                  
for name in customer:
    print(name)
# Out:
# Arhaan
# Prajwal
# Keerthan

# %%
transactions = [500, -200, 1000, -700]
for num in transactions:
    if num > 0:
        print("Credit")
    elif num < 0:
        print("Debit")
# Out:
# Credit
# Debit
# Credit
# Debit

# %%
amounts = [6000,3000,7000,2000,4000]

# %%
for amount in amounts:
    if amount > 5000:
        print("Large")
    else:
        print("Small")
# Out:
# Large
# Small
# Large
# Small
# Small

# %%
balance = 10000
amount = int(input("enter a amount:"))
if amount <= balance:
    print("Debit successful")
else:
    print("Insufficient balance")
# Out:
# enter a amount: 300
# Debit successful

# %%
account = {"balance": 8000}
amount = int(input("enter a amount:"))
if amount <= account["balance"]:
    account["balance"] = account["balance"] - amount
    print("new balance")
else:
    print("Not enough balance")
# Out:
# enter a amount: 500
# new balance

# %%
transactions = [("Credit", 1000), ("Debit", 500)]

# %%
for transaction in transactions:
    if transaction[0] == "Credit":
        print("Added")
    else:
        print("Deducted")
# Out:
# Added
# Deducted
