# %%
def simple_interest (p,r,t):
    si=(p*r*t)/100
    return si

# %%
def compound_interest (p,r,t):
    Amount=p*(1+r/100)**t
    ci=Amount-p
    return ci

# %%
     p=int(input("enter the principle:"))
     r=int(input("enter the rate:"))
     t=int(input("enter the time:"))

     si=simple_interest(p,r,t)
     ci=compound_interest(p,r,t)

     print("simple_interest",si)
     print("compound_interest",ci)
# Out:
# enter the principle: 20000
# enter the rate: 6
# enter the time: 10
# simple_interest 12000.0
# compound_interest 15816.95393085709

# %%
n=int(input("enter the number of customers"))
for i in range(n):
    print("\n customers",i+1)
    p=int(input("enter the principle:"))
    r=int(input("enter the rate:"))
    t=int(input("enter the time:"))
    
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers 3
#  customers 1
# enter the principle: 30000
# enter the rate: 7
# enter the time: 3
# simple_interest 6300.0
# compound_interest 6751.290000000001
#
#  customers 2
# enter the principle: 50000
# enter the rate: 9
# enter the time: 6
# simple_interest 27000.0
# compound_interest 33855.00554205003
#
#  customers 3
# enter the principle: 40000
# enter the rate: 5
# enter the time: 2
# simple_interest 4000.0
# compound_interest 4100.0
